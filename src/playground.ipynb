# %%
import numpy as np

# %%
data = np.load('./data/model_0.npy', allow_pickle=True)

# %%
data.shape
# Out:
# (2,)

# %%
data[0].shape
# Out:
# (1000, 24)

# %%
data[0]

# %%
data[1].shape
# Out:
# (24,)

# %%
data[1]
# Out:
# array([ 72,  64,  60,  60,  68,  79,  87, 109, 141, 154, 162, 168, 174,
#        181, 186, 196, 211, 231, 252, 276, 302, 309, 301, 292])

# %%
data[0][0]
# Out:
# array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        8.99489552e-17, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00])

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(data[0])
plt.ylabel('some numbers')
plt.show()
